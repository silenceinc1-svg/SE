# %%
from attenuate import Denoiser
import torch
from data import *
from metrics import *
from losses import *
from train import *
from torch.optim import AdamW

# %%
attenuate_pretrained = Denoiser()
attenuate_pretrained.from_pretrained("PeaBrane/aTENNuate")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
attenuate_pretrained = attenuate_pretrained.to(device)
evaluate(attenuate_pretrained, test_data)
evaluate(attenuate_pretrained, shortened_train_data)

# %%
attenuate_training = Denoiser()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
attenuate_training = attenuate_training.to(device)

# %%
optim = AdamW(lr = 5e-3, params=attenuate_training.parameters(), weight_decay=0.02)
my_run_path = '/content/drive/MyDrive/aTTen_runs'
train_a_model(attenuate_training, attennuate_loss(), optim, train_data, shortened_train_data, evaluation_data, my_run_path)
